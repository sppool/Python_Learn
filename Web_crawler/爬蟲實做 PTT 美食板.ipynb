# %% [markdown]
# # [PTT 美食板](https://www.ptt.cc/bbs/Food/index.html)
#
# ### 導入套件

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Gen Jyuu Gothic P'] # 中文輸出(源柔黑體)
import sqlite3
import requests # 讀取網頁資料
import bs4

# %%
headers = {'user-agent':'Mozilla/5.0 (X11; Linux x86_64)'}
def get_soup(url, headers=headers):
    r = requests.get(url, headers=headers)
    rt = r.text
    soup = bs4.BeautifulSoup(rt, "html.parser")
    
    return soup

# %%
url = 'https://www.ptt.cc/bbs/Food/index.html'

soup = get_soup(url)
print(soup.prettify()) # 美食板主頁原始碼
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    看板 Food 文章列表 - 批踢踢實業坊
#   </title>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
#  </head>
#  <body>
#   <div id="topbar-container">
#    <div class="bbs-content" id="topbar">
#     <a href="/bbs/" id="logo">
#      批踢踢實業坊
#     </a>
#     <span>
#      ›
#     </span>
#     <a class="board" href="/bbs/Food/index.html">
#      <span class="board-label">
#       看板
#      </span>
#      Food
#     </a>
#     <a class="right small" href="/about.html">
#      關於我們
#     </a>
#     <a class="right small" href="/contact.html">
#      聯絡資訊
#     </a>
#    </div>
#   </div>
#   <div id="main-container">
#    <div id="action-bar-container">
#     <div class="action-bar">
#      <div class="btn-group btn-group-dir">
#       <a class="btn selected" href="/bbs/Food/index.html">
#        看板
#       </a>
#       <a class="btn" href="/man/Food/index.html">
#        精華區
#       </a>
#      </div>
#      <div class="btn-group btn-group-paging">
#       <a class="btn wide" href="/bbs/Food/index1.html">
#        最舊
#       </a>
#       <a class="btn wide" href="/bbs/Food/index7000.html">
#        ‹ 上頁
#       </a>
#       <a class="btn wide disabled">
#        下頁 ›
#       </a>
#       <a class="btn wide" href="/bbs/Food/index.html">
#        最新
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="r-list-container action-bar-margin bbs-screen">
#     <div class="search-bar">
#      <form action="search" id="search-bar" type="get">
#       <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
#      </form>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1578823836.A.469.html">
#        [食記] 首爾moment coffee 弘大延南洞2號店
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        miinhwa18
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E9%A3%9F%E8%A8%98%5D+%E9%A6%96%E7%88%BEmoment+coffee+%E5%BC%98%E5%A4%A7%E5%BB%B6%E5%8D%97%E6%B4%9E2%E8%99%9F%E5%BA%97+">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3Amiinhwa18">
#           搜尋看板內 miinhwa18 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        1/12
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f2">
#        2
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1578827308.A.EDD.html">
#        [食記] 台北信義 松發肉骨茶-遠東信義A13
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        qo85960
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E9%A3%9F%E8%A8%98%5D+%E5%8F%B0%E5%8C%97%E4%BF%A1%E7%BE%A9+%E6%9D%BE%E7%99%BC%E8%82%89%E9%AA%A8%E8%8C%B6-%E9%81%A0%E6%9D%B1%E4%BF%A1%E7%BE%A9A13">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3Aqo85960">
#           搜尋看板內 qo85960 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        1/12
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1578830622.A.E73.html">
#        [食記] 高雄 跟著市長吃透透系列之賽門汕頭火鍋
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        pink02
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E9%A3%9F%E8%A8%98%5D+%E9%AB%98%E9%9B%84+%E8%B7%9F%E8%91%97%E5%B8%82%E9%95%B7%E5%90%83%E9%80%8F%E9%80%8F%E7%B3%BB%E5%88%97%E4%B9%8B%E8%B3%BD%E9%96%80%E6%B1%95%E9%A0%AD%E7%81%AB%E9%8D%8B">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3Apink02">
#           搜尋看板內 pink02 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        1/12
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1578831467.A.53A.html">
#        [食記] 台北西門&amp;北車早餐吃到飽-享樂文旅(開封)
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        hellolego
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E9%A3%9F%E8%A8%98%5D+%E5%8F%B0%E5%8C%97%E8%A5%BF%E9%96%80%26%E5%8C%97%E8%BB%8A%E6%97%A9%E9%A4%90%E5%90%83%E5%88%B0%E9%A3%BD-%E4%BA%AB%E6%A8%82%E6%96%87%E6%97%85%28%E9%96%8B%E5%B0%81%29">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3Ahellolego">
#           搜尋看板內 hellolego 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        1/12
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1578836202.A.0CB.html">
#        [食記] 思鄉病 牛肉麵 遠百信義A13
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        osakaleo
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E9%A3%9F%E8%A8%98%5D+%E6%80%9D%E9%84%89%E7%97%85+%E7%89%9B%E8%82%89%E9%BA%B5+%E9%81%A0%E7%99%BE%E4%BF%A1%E7%BE%A9A13">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3Aosakaleo">
#           搜尋看板內 osakaleo 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        1/12
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1578837794.A.D2A.html">
#        Fw: [食記] 熊本 黑亭拉麵 下通店
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        chrisxmen
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E9%A3%9F%E8%A8%98%5D+%E7%86%8A%E6%9C%AC+%E9%BB%91%E4%BA%AD%E6%8B%89%E9%BA%B5+%E4%B8%8B%E9%80%9A%E5%BA%97">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3Achrisxmen">
#           搜尋看板內 chrisxmen 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        1/12
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1578838108.A.DCD.html">
#        [食記] 台北市文山區-永和豆漿大王(木新店)
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        fatlee
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E9%A3%9F%E8%A8%98%5D+%E5%8F%B0%E5%8C%97%E5%B8%82%E6%96%87%E5%B1%B1%E5%8D%80-%E6%B0%B8%E5%92%8C%E8%B1%86%E6%BC%BF%E5%A4%A7%E7%8E%8B%28%E6%9C%A8%E6%96%B0%E5%BA%97%29">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3Afatlee">
#           搜尋看板內 fatlee 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        1/12
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1578838340.A.DA7.html">
#        [食記] 台北萬華 壽司王
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        thudadai
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E9%A3%9F%E8%A8%98%5D+%E5%8F%B0%E5%8C%97%E8%90%AC%E8%8F%AF+%E5%A3%BD%E5%8F%B8%E7%8E%8B">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3Athudadai">
#           搜尋看板內 thudadai 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        1/12
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1578838516.A.40F.html">
#        [食記] 台北 忠孝SOGO 海記 醬油雞 雞肉軟嫩多汁
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        jay70134
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E9%A3%9F%E8%A8%98%5D+%E5%8F%B0%E5%8C%97+%E5%BF%A0%E5%AD%9DSOGO+%E6%B5%B7%E8%A8%98+%E9%86%AC%E6%B2%B9%E9%9B%9E+%E9%9B%9E%E8%82%89%E8%BB%9F%E5%AB%A9%E5%A4%9A%E6%B1%81">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3Ajay70134">
#           搜尋看板內 jay70134 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        1/12
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1578839178.A.C46.html">
#        [食記] 福岡 太宰府 蘭館 焙煎珈琲 厚蛋燒三明治
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        jay70134
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E9%A3%9F%E8%A8%98%5D+%E7%A6%8F%E5%B2%A1+%E5%A4%AA%E5%AE%B0%E5%BA%9C+%E8%98%AD%E9%A4%A8+%E7%84%99%E7%85%8E%E7%8F%88%E7%90%B2+%E5%8E%9A%E8%9B%8B%E7%87%92%E4%B8%89%E6%98%8E%E6%B2%BB">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3Ajay70134">
#           搜尋看板內 jay70134 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        1/12
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1578840851.A.103.html">
#        [食記] 台北士林 CP值高美味日式料理-多摩食堂
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        hello5566
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E9%A3%9F%E8%A8%98%5D+%E5%8F%B0%E5%8C%97%E5%A3%AB%E6%9E%97+CP%E5%80%BC%E9%AB%98%E7%BE%8E%E5%91%B3%E6%97%A5%E5%BC%8F%E6%96%99%E7%90%86-%E5%A4%9A%E6%91%A9%E9%A3%9F%E5%A0%82">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3Ahello5566">
#           搜尋看板內 hello5566 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        1/12
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1578841342.A.572.html">
#        [食記] 台北木柵 小廢墟咖啡Ruins Coffee Roasters
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        g39958
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E9%A3%9F%E8%A8%98%5D+%E5%8F%B0%E5%8C%97%E6%9C%A8%E6%9F%B5+%E5%B0%8F%E5%BB%A2%E5%A2%9F%E5%92%96%E5%95%A1Ruins+Coffee+Roasters">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3Ag39958">
#           搜尋看板內 g39958 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        1/12
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1578842005.A.BAB.html">
#        [食記] 台北 華泰王子飯店 九華樓
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        hwatai
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E9%A3%9F%E8%A8%98%5D+%E5%8F%B0%E5%8C%97+%E8%8F%AF%E6%B3%B0%E7%8E%8B%E5%AD%90%E9%A3%AF%E5%BA%97+%E4%B9%9D%E8%8F%AF%E6%A8%93">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3Ahwatai">
#           搜尋看板內 hwatai 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        1/12
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1578842985.A.236.html">
#        [食記] 陳Q古早味黑砂糖剉冰｜台北臨江通化夜市
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        v84454058
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E9%A3%9F%E8%A8%98%5D+%E9%99%B3Q%E5%8F%A4%E6%97%A9%E5%91%B3%E9%BB%91%E7%A0%82%E7%B3%96%E5%89%89%E5%86%B0%EF%BD%9C%E5%8F%B0%E5%8C%97%E8%87%A8%E6%B1%9F%E9%80%9A%E5%8C%96%E5%A4%9C%E5%B8%82">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3Av84454058">
#           搜尋看板內 v84454058 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        1/12
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1578845480.A.37E.html">
#        [食記] 桃園中壢區。很牛炭燒牛排
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        larle
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E9%A3%9F%E8%A8%98%5D+%E6%A1%83%E5%9C%92%E4%B8%AD%E5%A3%A2%E5%8D%80%E3%80%82%E5%BE%88%E7%89%9B%E7%82%AD%E7%87%92%E7%89%9B%E6%8E%92">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3Alarle">
#           搜尋看板內 larle 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        1/13
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1578846180.A.292.html">
#        [食記] 板橋江子翠。小喬新疆羊肉串~大盤雞好吃
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        paiyeu
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E9%A3%9F%E8%A8%98%5D+%E6%9D%BF%E6%A9%8B%E6%B1%9F%E5%AD%90%E7%BF%A0%E3%80%82%E5%B0%8F%E5%96%AC%E6%96%B0%E7%96%86%E7%BE%8A%E8%82%89%E4%B8%B2~%E5%A4%A7%E7%9B%A4%E9%9B%9E%E5%A5%BD%E5%90%83">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3Apaiyeu">
#           搜尋看板內 paiyeu 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        1/13
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f2">
#        4
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1578846857.A.A0B.html">
#        [食記] 高雄 汕頭泉成沙茶火鍋總店 偏貴的古早味
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        kamgx58
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E9%A3%9F%E8%A8%98%5D+%E9%AB%98%E9%9B%84+%E6%B1%95%E9%A0%AD%E6%B3%89%E6%88%90%E6%B2%99%E8%8C%B6%E7%81%AB%E9%8D%8B%E7%B8%BD%E5%BA%97+%E5%81%8F%E8%B2%B4%E7%9A%84%E5%8F%A4%E6%97%A9%E5%91%B3">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3Akamgx58">
#           搜尋看板內 kamgx58 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        1/13
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-list-sep">
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1355673582.A.5F7.html">
#        [公告] Food板 板規 V3.91
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        Dilbert
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+Food%E6%9D%BF+%E6%9D%BF%E8%A6%8F+V3.91">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3ADilbert">
#           搜尋看板內 Dilbert 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        12/16
#       </div>
#       <div class="mark">
#        !
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        18
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1190944426.A.E6C.html">
#        [公告] 發文請在標題加上地區及提供地址電話。^^
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        bluefish
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E7%99%BC%E6%96%87%E8%AB%8B%E5%9C%A8%E6%A8%99%E9%A1%8C%E5%8A%A0%E4%B8%8A%E5%9C%B0%E5%8D%80%E5%8F%8A%E6%8F%90%E4%BE%9B%E5%9C%B0%E5%9D%80%E9%9B%BB%E8%A9%B1%E3%80%82%5E%5E">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3Abluefish">
#           搜尋看板內 bluefish 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        9/28
#       </div>
#       <div class="mark">
#        !
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1128132666.A.0FD.html">
#        [公告] 文章被刪除者請洽精華區的資源回收桶
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        Dilbert
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%96%87%E7%AB%A0%E8%A2%AB%E5%88%AA%E9%99%A4%E8%80%85%E8%AB%8B%E6%B4%BD%E7%B2%BE%E8%8F%AF%E5%8D%80%E7%9A%84%E8%B3%87%E6%BA%90%E5%9B%9E%E6%94%B6%E6%A1%B6">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3ADilbert">
#           搜尋看板內 Dilbert 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        10/01
#       </div>
#       <div class="mark">
#        !
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f2">
#        4
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/Food/M.1496532469.A.C36.html">
#        [公告] 新增板規22：發文禁附延伸閱讀連結
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        Dilbert
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Food/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%96%B0%E5%A2%9E%E6%9D%BF%E8%A6%8F22%EF%BC%9A%E7%99%BC%E6%96%87%E7%A6%81%E9%99%84%E5%BB%B6%E4%BC%B8%E9%96%B1%E8%AE%80%E9%80%A3%E7%B5%90">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Food/search?q=author%3ADilbert">
#           搜尋看板內 Dilbert 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        6/04
#       </div>
#       <div class="mark">
#        !
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
#   </script>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js">
#   </script>
#   <script src="//images.ptt.cc/bbs/v2.27/bbs.js">
#   </script>
#  </body>
# </html>

# %% [markdown]
# ### 從超連結中找出上頁的連結

# %%
def get_up_page(soup):
    for a in soup.find_all('a'):
        if '上頁' in a.get_text():
            up_page = 'https://www.ptt.cc' + a['href']
            break
            
    return up_page

# %%
new_url = get_up_page(soup)
new_url
# Out:
# 'https://www.ptt.cc/bbs/Food/index7000.html'

# %%
soup = get_soup(url)
get_up_page(soup)
# Out:
# 'https://www.ptt.cc/bbs/Food/index7000.html'

# %% [markdown]
# ### 抓取頁面中的"食記"標題

# %%
def print_tag(soup, tag='[食記]'):
    for a in soup.find_all('a'):
        at = a.get_text()
        if tag in at and 'Re' not in at and 'Fw' not in at:
            print(at)

# %%
print_tag(soup)
# Out:
# [食記] 首爾moment coffee 弘大延南洞2號店
# [食記] 台北信義 松發肉骨茶-遠東信義A13
# [食記] 高雄 跟著市長吃透透系列之賽門汕頭火鍋
# [食記] 台北西門&北車早餐吃到飽-享樂文旅(開封)
# [食記] 思鄉病 牛肉麵 遠百信義A13
# [食記] 台北市文山區-永和豆漿大王(木新店)
# [食記] 台北萬華 壽司王
# [食記] 台北 忠孝SOGO 海記 醬油雞 雞肉軟嫩多汁
# [食記] 福岡 太宰府 蘭館 焙煎珈琲 厚蛋燒三明治
# [食記] 台北士林 CP值高美味日式料理-多摩食堂
# [食記] 台北木柵 小廢墟咖啡Ruins Coffee Roasters
# [食記] 台北 華泰王子飯店 九華樓
# [食記] 陳Q古早味黑砂糖剉冰｜台北臨江通化夜市
# [食記] 桃園中壢區。很牛炭燒牛排
# [食記] 板橋江子翠。小喬新疆羊肉串~大盤雞好吃
# [食記] 高雄 汕頭泉成沙茶火鍋總店 偏貴的古早味

# %% [markdown]
# ### 主頁開始抓n頁所有"食記"

# %%
url = 'https://www.ptt.cc/bbs/Food/index.html'
n = 3

for i in range(n):
    soup = get_soup(url)
    print(url)
    print_tag(soup)
    url = get_up_page(soup)
# Out:
# https://www.ptt.cc/bbs/Food/index.html
# [食記] 首爾moment coffee 弘大延南洞2號店
# [食記] 台北信義 松發肉骨茶-遠東信義A13
# [食記] 高雄 跟著市長吃透透系列之賽門汕頭火鍋
# [食記] 台北西門&北車早餐吃到飽-享樂文旅(開封)
# [食記] 思鄉病 牛肉麵 遠百信義A13
# [食記] 台北市文山區-永和豆漿大王(木新店)
# [食記] 台北萬華 壽司王
# [食記] 台北 忠孝SOGO 海記 醬油雞 雞肉軟嫩多汁
# [食記] 福岡 太宰府 蘭館 焙煎珈琲 厚蛋燒三明治
# [食記] 台北士林 CP值高美味日式料理-多摩食堂
# [食記] 台北木柵 小廢墟咖啡Ruins Coffee Roasters
# [食記] 台北 華泰王子飯店 九華樓
# [食記] 陳Q古早味黑砂糖剉冰｜台北臨江通化夜市
# [食記] 桃園中壢區。很牛炭燒牛排
# [食記] 板橋江子翠。小喬新疆羊肉串~大盤雞好吃
# [食記] 高雄 汕頭泉成沙茶火鍋總店 偏貴的古早味
# https://www.ptt.cc/bbs/Food/index7000.html
# [食記] 彰化 南園食堂 童趣偉士牌喵星人老屋
# [食記] 台北 窩窩 wooo~老花窗裡的港式美味
# [食記] 台北北投 蓬萊台菜餐廳
# [食記] 高雄 Zakuzaku 棒棒泡芙 好吃的日式甜點
# [食記] 桃園平鎮區。三禾手打麵
# [食記] 台北 Truffles Aroma舒服氣息
# [食記] 台北中山 祥雲龍吟 米其林二星 再訪 懷石創意料理
# [食記][台北市] 佐藤咖哩 Sato Curry 和平店
# [食記] 馬來西亞馬六甲Jonker 88 椰漿飯叻沙煎蕊
# [食記] 高雄 好好吃肉韓式烤肉吃到飽 食肉怪必吃
# [食記] 台南 邱家小卷米粉
# [食記] 台北 coffet dpt：美式軟餅乾之王之特濃
# [食記] 高雄 右昌肉圓
# [食記] 宜蘭 泥鰍 在復古的美好年代裡品嘗咖哩飯
# [食記] 新北板橋 金色三麥(板橋大遠百店)
# [食記] 新北金山三倍大芋圓地瓜圓 金山芋圓王
# [食記] 台中 空也素麵食 輕井澤蔬食鍋物改版
# [食記] 內湖食將王鐵板燒 平價鐵板燒餐廳
# [食記] 首爾咖啡Fritz Coffee Company
# https://www.ptt.cc/bbs/Food/index6999.html
# [食記] [台南][新營] 阿松臭豆腐(圖少)
# [食記] 高雄 秘燒時尚岩燒牛排 自己的牛排自己煎
# [食記] 台南 北區 小北平餡餅粥
# [食記] 台南 東區 鹿耳深夜甜點
# [食記] 台南 中西區 泰灣曼谷
# [食記] 台北市文山區忠順街上-四麵八餃
# [食記] 台北中山 燒肉HATSU Yakiniku & Wine
# [食記] 香港 旺角 金華冰廳
# [食記] 桃園中壢區。Mr.三明治
# [食記] 桃園。正一排骨
# [食記] 首爾 益善洞 韓屋咖啡廳-庭院花房
# [食記] 日本由布院日式旅館御宿有樂-餐食篇
# [食記] 台南 中西區 熨斗目花珈琲 珈哩 cafe WUDAO
# [食記] 台北 旭集假日午餐吃到飽 松葉蟹干貝和牛
# [食記] 台南 安平區 天馬星空餐酒館
# [食記] 台南 北區 Selamat datang｜馬來西亞料理
# [食記] 台北信義 LADY M 大遠百A13 只推千層
# [食記] 金山美食 漳聖王廟前 金包里鴨肉ㄜˋ

# %%
def print_tag_lst(soup, lst, tag='[食記]'):
    for a in soup.find_all('a'):
        at = a.get_text()
        if tag in at and 'Re' not in at and 'Fw' not in at:
            lst.append(at)

# %% [markdown]
# ### 爬蟲開始爬 先把資料存在lst

# %%
page = 3450
n = 2
lst = []

for i in range(n):
    url = 'https://www.ptt.cc/bbs/Food/index' + str(page) + '.html'
    soup = get_soup(url)
    print(url)
    print_tag_lst(soup, lst)
    page -= 1
# Out:
# https://www.ptt.cc/bbs/Food/index3450.html
# https://www.ptt.cc/bbs/Food/index3449.html

# %% [markdown]
# ### 寫入資料庫 food.db

# %% [raw]
# conn = sqlite3.connect('food.db')
# c = conn.cursor()
#
# # c.execute('CREATE TABLE pttfood(id INTEGER PRIMARY KEY, label TEXT);')
# # conn.commit()
#
# # c.execute('DROP TABLE pttfood')
# # conn.commit()
#
# for t in lst:
#     c.execute('INSERT INTO pttfood(label) VALUES(?);', (t, ))
# conn.commit()
# conn.close()

# %% [markdown]
# ### 讀出資料庫的資料 轉成pd.DataFramea

# %%
conn = sqlite3.connect('food.db')
c = conn.cursor()
df = pd.DataFrame(c.execute('SELECT * FROM pttfood'), columns=[row[0] for row in c.description])
conn.close()

df
# Out:
#             id                         label
# 0            1  [食記] 沖繩｜恩納村｜夏威夷鬆餅屋 Paanilani
# 1            2      [食記] 日本正夯的生食吐司vs台中二家生食吐司
# 2            3      [食記] 台北大安區龍門國中附近-呂巷仔口麵食館
# 3            4       [食記] 台中 俺の食堂 板前燒肉一徹中午定食
# 4            5              [食記] 台中 KoDo和牛燒肉
# ...        ...                           ...
# 111967  111968                  [食記] 嘉義紅花鐵板燒
# 111968  111969                  [食記] 中壢。福利川菜
# 111969  111970               [食記] 中推神牛炭火日式燒肉
# 111970  111971                    [食記] 台大知多家
# 111971  111972                   [食記] ㄒㄧㄢ霸慶生
#
# [111972 rows x 2 columns]

# %% [markdown]
# ### 設定需要的小吃 寫入分類
# * `pandas.Series.str.contains` 尋找字串是否存在

# %%
def create_city_count(rows, columns, num):
    city_count = pd.DataFrame(0, index=rows, columns=columns)
    for city in rows[:num]:
        for food in columns:
            city_count[food][city] = (df['label'].str.contains(city) & df['label'].str.contains(food)).sum()


    return city_count, columns

# %%
city_list = ['台北', '新北', '新竹', '台中', '台南', '高雄', '基隆', '桃園', '苗栗', '南投', '彰化', '雲林', '嘉義', 
             '屏東', '宜蘭', '花蓮', '台東', '澎湖', '金門', '連江']
food_list = ['飯', '麵', '雞', '鴨', '豬', '牛', '羊', '魚', '餃', '素', '肉', '湯', '羹', '粽', '鍋', '壽司',
             '便當', '咖啡', '茶', '酒', '冰']

# %%
city_count, columns = create_city_count(city_list, food_list, 6)
city_count.head(6)
# Out:
#        飯     麵     雞    鴨    豬     牛    羊    魚    餃    素  ...    湯   羹   粽  \
# 台北  1803  4441  1044  257  628  2137  144  729  375  203  ...  874  94  22
# 新北   311   639   165   78   78   281   54  125   58   29  ...  107  61  15
# 新竹   264   548   120   75   68   279   29  127   64   23  ...  101  13   8
# 台中   456  1065   277   92  140   520   38  210   91   52  ...  253  64   6
# 台南   463   834   288  124  163   624  101  466   68   41  ...  473  93  52
# 高雄   474   879   252  151  114   451   65  207  127   65  ...  203  46  30
#
#        鍋   壽司  便當    咖啡     茶     酒    冰
# 台北  2023  399  71  2531  1760  1626  632
# 新北   426   71  21   324   189   107  103
# 新竹   240   25  17   304   144   124   58
# 台中   539  133  52   762   502   208  310
# 台南   468  100  16   435   475   178  419
# 高雄   469  185  28   496   538   227  247
#
# [6 rows x 21 columns]

# %% [markdown]
# ### 資料正規化

# %%
arr = city_count.values[0:6] 
arr = arr / arr.sum(1)[:, np.newaxis] # (city.sum()) 全部比例縮放
arr = arr / arr.max(0) # (food.max()) 最大值縮放
arr = np.nan_to_num(arr) # 避免全0狀況

# %% [markdown]
# ### 製圖

# %%
ar =  np.concatenate((arr, arr[:, 0:1]), axis=1)

fig = plt.figure(figsize=(10, 10))
ax = fig.add_axes([0, 0, 1, 1], projection='polar', facecolor='#ffeedd')

angle = np.linspace(0, 2*np.pi, ar.shape[1])
for i in range(ar.shape[0]):
    ax.plot(angle, ar[i], 'o--', ms=10, lw=1.8, label=city_list[i], alpha=0.75)
for i in range(ar.shape[1]-1):
    ax.text(angle[i], 1.075, columns[i], fontsize=18, 
            horizontalalignment='center', verticalalignment='center')

# plt.ylim([0, 1.025])
plt.xticks(np.linspace(0, 2*np.pi, ar.shape[1]), [])
ax.grid(True)
plt.legend(loc=1, fontsize=15)

# %%
fig = plt.figure(figsize=(16, 8))
for i in range(arr.shape[0]):
    plt.plot(arr[i], 'o--', lw=1.8, label=city_list[i])
plt.xticks(np.arange(arr.shape[1]), columns, fontsize=18)
plt.yticks(fontsize=15)
plt.grid(True)
plt.legend(fontsize=15)

# %% [markdown]
# ### 討論魚的細部分類

# %%
df[df.label.str.contains('魚')]
# Out:
#             id                            label
# 21          22           [食記] 西門城中市場-很台南道味的虱目魚粥
# 26          27  [食記] 金澤 肉質細緻的喉黑魚飯三吃 のど黒めし本舗 いたる
# 41          42         [食記] 台南 咘。甜不辣 台北甜不辣、鮭魚炒飯
# 78          79          [食記]板橋 尋麻記~和想像中不同的水煮魚料理
# 127        128       [食記] 台北-- 用虹吸壺煮魚湯的綻1852牛排館
# ...        ...                              ...
# 111782  111783                       [食記] 台中人魚家
# 111785  111786                 [食記] 屏東 東港黑鮪魚初體驗
# 111878  111879        [食記] 高雄 漢來 池畔餐廳 墨魚麵好好吃^@^
# 111882  111883                [食記] 草屯魷魚粳 肉圓 蚵仔嗲
# 111896  111897        [食記] 超奢華美食＠『克羅采』：黑鮪魚烤下巴 …
#
# [3022 rows x 2 columns]

# %%
fish_list = ['魚', '虱目魚', '鮭魚', '鮪魚', '鱸魚', '魷魚', '章魚', '鰻魚', '土魠魚', '鮑魚', '生魚片', '魚麵', 
             '魚頭', '魚皮', '魚肚', '魚湯', '魚丸']
city_count, columns = create_city_count(city_list, fish_list, 6)
city_count.head(6)
# Out:
#       魚  虱目魚  鮭魚  鮪魚  鱸魚  魷魚  章魚  鰻魚  土魠魚  鮑魚  生魚片  魚麵  魚頭  魚皮  魚肚  魚湯  魚丸
# 台北  729   27  43  17   3  47  15  67    8  15  118  12   4   0  15  13  18
# 新北  125    5   5   7   2  16   4   1    3   2   16   4   1   0   0   3   3
# 新竹  127    4  16   3   2   3   3   0    1   0    9   6   0   1   2   3  10
# 台中  210    6   7   1   2  11   9  18    0   4   31   2   1   0   3   4   5
# 台南  466  111   5   2   1   0   7   6   45   7    5  31   4  29  10  25  20
# 高雄  207   22   7  17   1   4  17   9   15   3   25   7   0   2   5  14   6

# %%
arr = city_count.values[0:6] 
arr = arr / arr.max(1)[:, np.newaxis] # 最大值 即 "魚"
arr = arr / arr.max(0)
arr = np.nan_to_num(arr) # 避免全0狀況

ar =  np.concatenate((arr, arr[:, 0:1]), axis=1)

fig = plt.figure(figsize=(10, 10))
ax = fig.add_axes([0, 0, 1, 1], projection='polar', facecolor='#ffeedd')

angle = np.linspace(0, 2*np.pi, ar.shape[1])
for i in range(ar.shape[0]):
    ax.plot(angle, ar[i], 'o--', ms=10, lw=1.8, label=city_list[i], alpha=0.7)
for i in range(ar.shape[1]-1):
    ax.text(angle[i], 1.175, columns[i], fontsize=18, 
            horizontalalignment='center', verticalalignment='center')

plt.ylim([-0.4, 1.025])
plt.xticks(np.linspace(0, 2*np.pi, ar.shape[1]), [])
ax.grid(True)
plt.legend(loc=1, fontsize=15)
# Out:
# /home/sppool/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 39776 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/sppool/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 39776 missing from current font.
#   font.set_text(s, 0, flags=flags)
