# %% [markdown]
# # [geopandas](http://geopandas.org/)
# * 圖資顯示模組

# %%
import numpy as np
import pandas as pd
import geopandas as gp
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Taipei Sans TC Beta'] # 中文輸出(台北黑體)
# %matplotlib inline
import pickle

# %%
mapp1 = gp.read_file('臺鐵鐵路路線/RAIL_1090102.shp')
mapp2 = gp.read_file('臺鐵車站_1090102/MARK_臺鐵車站_1090102.shp')
mapp3 = gp.read_file('國省道_含快速公路_1090102/ROAD_國省道(含快速公路)_1090102.shp')

# %%
mapp1.plot(figsize=(8, 8))

# %%
mapp2.plot(figsize=(8, 8), '.')

# %%
mapp3.plot(figsize=(8, 8))

# %%
print(mapp1.shape)
print(mapp2.shape)
print(mapp3.shape)
# Out:
# (950, 7)
# (263, 9)
# (55701, 24)

# %%
mapp1.head(5)
# Out:
#         RAILID   RAILNAME  RAILTYPE   MDATE  SOURCE  DEFINITION  \
# 0  A0000000002  臺鐵縱貫線(北段)         3  201906       0           1
# 1  A0000000003  臺鐵縱貫線(北段)         3  201906       0           1
# 2  A0000000004  臺鐵縱貫線(北段)         3  201906       0           1
# 3  A0000000005  臺鐵縱貫線(北段)         3  201906       0           1
# 4  C0000000004      臺鐵深澳線         2  201311       0           0
#
#                                             geometry
# 0  LINESTRING (299180.901 2768898.613, 299301.099...
# 1  LINESTRING (303403.551 2770996.349, 303400.496...
# 2  LINESTRING (303403.551 2770996.349, 303400.372...
# 3  LINESTRING (303403.551 2770996.349, 303610.587...
# 4  LINESTRING (330473.832 2778957.754, 330473.808...

# %%
mapp2.head(5)
# Out:
#         MARKID MARKTYPE1 MARKTYPE2 MARKNAME1 MARKNAME2   MDATE  \
# 0  B0000011964   9960101      None    臺鐵豐原車站     臺鐵豐原站  201911
# 1  B0000006991   9960101      None    臺鐵栗林車站     臺鐵栗林站  201911
# 2  B0000001360   9960101      None    臺鐵烏日車站     臺鐵烏日站  201310
# 3  B0000006988   9960101      None   臺鐵新烏日車站    臺鐵新烏日站  201710
# 4  B0000000923   9960101      None    臺鐵成功車站     臺鐵成功站  201310
#
#            ADDRESS          TEL                        geometry
# 0    臺中市豐原區中正路1-1號  04-25207950  POINT (221925.619 2683206.277)
# 1  臺中市潭子區潭豐路二段747號  04-25391401  POINT (220614.975 2681033.160)
# 2    臺中市烏日區三民街258號  04-23381071  POINT (211624.009 2667112.158)
# 3   臺中市烏日區高鐵東一路26號  04-23376883  POINT (210790.213 2667233.415)
# 4  臺中市烏日區中山路三段550號  04-23371986  POINT (208340.212 2667741.078)

# %%
mapp3.head(5)
# Out:
#      ROADSEGID ROADCLASS1 ROADCLASS2 ROADCODE COUNTY  ROADSTRUCT ROADNUM  \
# 0  U0000061701         1W    9440202     0090    花蓮縣           1      台9
# 1  U0000061702         1W    9440202     0090    花蓮縣           1      台9
# 2  U0000061703         1W    9420201     0090    花蓮縣           0      台9
# 3  U0000061704         1U    9420201     0090    花蓮縣           0      台9
# 4  U0000061705         1U    9420201     0090    花蓮縣           0      台9
#
#   ROADNUM1 ROADNUM2 ROADNAME  ... RDNAMELANE RDNAMENON WIDTH      FNODE  \
# 0     None     None     None  ...       None      None    25  S8UV2JVT6
# 1     None     None     None  ...       None      None    25  S8UTEJW94
# 2     None     None     None  ...       None      None    25  S8V24JX5V
# 3     None     None      中正路  ...       None      None    25  S8XC4K1VD
# 4     None     None      中正路  ...       None      None    25  S8X27K1RD
#
#        TNODE   MDATE  SOURCE DEFINITION DIR  \
# 0  S8UTUJW95  201909       8          0   1
# ...
