# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline

# %%
plt.plot(np.random.uniform(size=3000), 'og')

# %%
plt.plot(np.random.rand(3000), 'og')

# %%
plt.plot(np.random.random(3000), 'og')

# %%
plt.plot(np.random.normal(0, 1, 5000), '.g')

# %%
plt.plot(np.random.randn(5000), '.g')

# %% [markdown]
# ![Image of Yaktocat](https://docs.scipy.org/doc/numpy/_images/math/2b1e6bf9bbcf920df868e620fca52a07584c804c.svg)

# %%
plt.plot(np.random.power(3 , size=3000), '.g')

# %%
plt.plot(np.random.choice(10, size=1000), '.g') # 0~9 random

# %%
plt.plot(np.random.poisson(2, size=3000), '.g') # 帕松分布

# %%
plt.plot(np.random.binomial(10, 0.5, size=2000), '.g') # 二項分布
